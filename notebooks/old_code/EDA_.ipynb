# %% [markdown]
# # EDa

# %%
6+6
# Out:
# 12

# %%
# Core imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../dataset/data.csv')
print(df.shape)
#df = df.head(1000)
df
# Out:
# (39942, 5)
#        label                                              title  \
# 0          1  As U.S. budget fight looms, Republicans flip t...
# 1          1  U.S. military to accept transgender recruits o...
# 2          1  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3          1  FBI Russia probe helped by Australian diplomat...
# 4          1  Trump wants Postal Service to charge 'much mor...
# ...      ...                                                ...
# 39937      0  THIS IS NOT A JOKE! Soros-Linked Group Has Pla...
# 39938      0  THE SMARTEST WOMAN In Politics: “How Trump Can...
# 39939      0  BREAKING! SHOCKING VIDEO FROM CHARLOTTE RIOTS:...
# 39940      0  BREAKING! Charlotte News Station Reports Cops ...
# 39941      0  BIG MISTAKE! HILLARY JUST Proved To America Sh...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 39937  The Left has been organizing for decades, and ...     left-news
# 39938  Monica Crowley offers some of the most brillia...     left-news
# 39939  Protest underway in Charlotte:  Things got com...     left-news
# 39940  Local Charlotte, NC news station WSOCTV is rep...     left-news
# 39941  Dividing America will be Obama s legacy. Hilla...     left-news
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 39937        Sep 22, 2016
# 39938        Sep 22, 2016
# 39939        Sep 21, 2016
# 39940        Sep 21, 2016
# 39941        Sep 21, 2016
#
# [39942 rows x 5 columns]

# %% [markdown]
# ## 1. Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39942 entries, 0 to 39941
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    39942 non-null  int64
#  1   title    39942 non-null  str
#  2   text     39942 non-null  str
#  3   subject  39942 non-null  str
#  4   date     39942 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 96.7 MB

# %%
print("Shape:", df.shape)
print("\nMissing values: ", df.isnull().sum().sum())
df.info()
# Out:
# Shape: (39942, 5)
#
# Missing values:  0
# <class 'pandas.DataFrame'>
# RangeIndex: 39942 entries, 0 to 39941
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    39942 non-null  int64
#  1   title    39942 non-null  str
#  2   text     39942 non-null  str
#  3   subject  39942 non-null  str
#  4   date     39942 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 96.7 MB

# %%
# --- Label distribution ---
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

sns.countplot(x='label', data=df, ax=ax[0])
ax[0].set_title('Label Distribution (count)')

df['label'].value_counts(normalize=True).plot.pie(
    autopct='%1.1f%%', ax=ax[1], ylabel=''
)
ax[1].set_title('Label Distribution (%)')

plt.tight_layout()
plt.show()

# %%
# --- Categorical column distribution (e.g. subject) ---
plt.figure(figsize=(6, 4))
sns.countplot(x='subject', data=df, order=df['subject'].value_counts().index)
plt.title('Subject Distribution')
plt.show()

# Label distribution across categories — useful to spot imbalance/bias per group
plt.figure(figsize=(6, 4))
sns.countplot(x='subject', hue='label', data=df)
plt.title('Label Distribution by subject')
plt.show()

# %%
df['subject'].value_counts()
# Out:
# subject
# politicsNews       11272
# News                9050
# worldnews           8727
# politics            6841
# left-news           2482
# Government News     1570
# Name: count, dtype: int64

# %%
## there is clear data leak from this column
sns.countplot(x='subject', data=df)
pd.crosstab(df['subject'], df['label'])
# Out:
# label               0      1
# subject
# Government News  1570      0
# News             9050      0
# left-news        2482      0
# politics         6841      0
# politicsNews        0  11272
# worldnews           0   8727

# %%
# --- Text length distribution (quick sanity check per text column) ---
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

df['title'].str.split().apply(len).plot.hist(ax=ax[0], bins=10)
ax[0].set_title('Title Word Count')

df['text'].str.split().apply(len).plot.hist(ax=ax[1], bins=10)
ax[1].set_title('Text Word Count')

plt.tight_layout()
plt.show()

# %%
#--- Date distribution ---
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df.groupby(df['date'].dt.to_period('M'))['label'].value_counts().unstack().plot()
# Out:
# <Axes: xlabel='date'>

# %%
#--- Text length per label ---
df['text_len'] = df['text'].str.split().apply(len)
sns.histplot(data=df, x='text_len', hue='label', bins=50)
# Out:
# <Axes: xlabel='text_len', ylabel='Count'>

# %%
# df.shape, df.info(), df.isnull().sum(), df.duplicated().sum()

# --- Label distribution ---
# sns.countplot(x='label', data=df)

# --- Subject distribution & leakage check ---
# sns.countplot(x='subject', data=df)
# pd.crosstab(df['subject'], df['label'])   # <-- IMPORTANT: check if subject perfectly separates classes

# --- Date distribution ---
# df['date'] = pd.to_datetime(df['date'], errors='coerce')
# df.groupby(df['date'].dt.to_period('M'))['label'].value_counts().unstack().plot()

# --- Text length per label ---
# df['text_len'] = df['text'].str.split().apply(len)
# sns.histplot(data=df, x='text_len', hue='label', bins=50)

# %%
df['date'].value_counts() # some dates are not converteable.
# Out:
# date
# December 20, 2017                                                                                                           182
# December 6, 2017                                                                                                            166
# November 30, 2017                                                                                                           162
# November 9, 2017                                                                                                            158
# October 13, 2017                                                                                                            155
#                                                                                                                            ...
# Apr 1, 2015                                                                                                                   1
# Sep 10, 2015                                                                                                                  1
# Jun 21, 2015                                                                                                                  1
# May 2, 2015                                                                                                                   1
# MSNBC HOST Rudely Assumes Steel Worker Would Never Let His Son Follow in His Footsteps…He Couldn’t Be More Wrong [Video]      1
# Name: count, Length: 2392, dtype: int64

# %% [markdown]
# # comments
# - Drop subject
#   - clear distinction between the labels. Some subjects clearly predict the label. so there is data leak
# - Drop date
#   - not relavent
#   - some dates not convertable
# - keep empty text for now ---> later come to it
#     - keep the columns and fill with empty strings - this might also contain info
#     - example - all text with len == 0 --> fake news (only 1 real news)
#     - - all title with len == 1 --> fake news (mostly links)

# %%
df[df[['title', 'text']].duplicated()]
# Out:
#        label                                              title  \
# 445        1  Senate tax bill stalls on deficit-focused 'tri...
# 778        1  Trump warns 'rogue regime' North Korea of grav...
# 892        1  Republicans unveil tax cut bill, but the hard ...
# 896        1  Trump taps Fed centrist Powell to lead U.S. ce...
# 974        1  Two ex-Trump aides charged in Russia probe, th...
# ...      ...                                                ...
# 39936      0  YIKES! Tomi Lahren DEMOLISHES Hillary: “How Da...
# 39937      0  THIS IS NOT A JOKE! Soros-Linked Group Has Pla...
# 39938      0  THE SMARTEST WOMAN In Politics: “How Trump Can...
# 39940      0  BREAKING! Charlotte News Station Reports Cops ...
# 39941      0  BIG MISTAKE! HILLARY JUST Proved To America Sh...
#
#                                                     text       subject  \
# 445    WASHINGTON (Reuters) - The U.S. Senate on Thur...  politicsNews
# 778    BEIJING (Reuters) - U.S. President Donald Trum...  politicsNews
# 892    WASHINGTON (Reuters) - U.S. House of Represent...  politicsNews
# 896    WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 974    WASHINGTON (Reuters) - Federal investigators p...  politicsNews
# ...                                                  ...           ...
# 39936  Wow! Bravo Tomi! You really nailed it this tim...     left-news
# 39937  The Left has been organizing for decades, and ...     left-news
# 39938  Monica Crowley offers some of the most brillia...     left-news
# 39940  Local Charlotte, NC news station WSOCTV is rep...     left-news
# 39941  Dividing America will be Obama s legacy. Hilla...     left-news
#
#             date    year  month year_month
# 445   2017-11-30  2017.0   11.0    2017-11
# 778   2017-11-08  2017.0   11.0    2017-11
# 892   2017-11-02  2017.0   11.0    2017-11
# 896   2017-11-02  2017.0   11.0    2017-11
# 974   2017-10-30  2017.0   10.0    2017-10
# ...          ...     ...    ...        ...
# 39936        NaT     NaN    NaN        NaT
# 39937        NaT     NaN    NaN        NaT
# 39938        NaT     NaN    NaN        NaT
# 39940        NaT     NaN    NaN        NaT
# 39941        NaT     NaN    NaN        NaT
#
# [3513 rows x 8 columns]

# %%
#--- Text length per label ---
df['text_len'] = df['text'].str.split().apply(len)
df['title_len'] = df['title'].str.split().apply(len)
df
# Out:
#        label                                              title  \
# 0          1  As U.S. budget fight looms, Republicans flip t...
# 1          1  U.S. military to accept transgender recruits o...
# 2          1  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3          1  FBI Russia probe helped by Australian diplomat...
# 4          1  Trump wants Postal Service to charge 'much mor...
# ...      ...                                                ...
# 39937      0  THIS IS NOT A JOKE! Soros-Linked Group Has Pla...
# 39938      0  THE SMARTEST WOMAN In Politics: “How Trump Can...
# 39939      0  BREAKING! SHOCKING VIDEO FROM CHARLOTTE RIOTS:...
# 39940      0  BREAKING! Charlotte News Station Reports Cops ...
# 39941      0  BIG MISTAKE! HILLARY JUST Proved To America Sh...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 39937  The Left has been organizing for decades, and ...     left-news
# 39938  Monica Crowley offers some of the most brillia...     left-news
# 39939  Protest underway in Charlotte:  Things got com...     left-news
# 39940  Local Charlotte, NC news station WSOCTV is rep...     left-news
# 39941  Dividing America will be Obama s legacy. Hilla...     left-news
#
#                      date  text_len  title_len
# 0      December 31, 2017        749         10
# 1      December 29, 2017        624          9
# 2      December 31, 2017        457         10
# 3      December 30, 2017        376          9
# 4      December 29, 2017        852         11
# ...                   ...       ...        ...
# 39937        Sep 22, 2016       841         20
# 39938        Sep 22, 2016       791         15
# 39939        Sep 21, 2016        26         12
# 39940        Sep 21, 2016       380         18
# 39941        Sep 21, 2016       171         16
#
# [39942 rows x 7 columns]

# %%
df.text_len.value_counts()
# Out:
# text_len
# 0       610
# 403     147
# 402     140
# 406     131
# 405     126
#        ...
# 2470      1
# 1383      1
# 4149      1
# 1202      1
# 1336      1
# Name: count, Length: 1454, dtype: int64

# %%
df[df['text_len'] < 10]#['label'].value_counts()
# Out:
#        label                                              title  \
# 8970       1                     Graphic: Supreme Court roundup
# 29357      0  https://100percentfedup.com/served-roy-moore-v...
# 30922      0  TAKE OUR POLL: Who Do You Think President Trum...
# 31040      0  Joe Scarborough BERATES Mika Brzezinski Over “...
# 31116      0  MY FAVORITE EXCUSES…Featuring Hillary Rotten C...
# ...      ...                                                ...
# 39866      0  UNREAL! OBAMA BLAMES SYRIAN CIVIL WAR ON CLIMA...
# 39894      0  WHAT WAS HE THINKING? DISHEVELED OBAMA YELLS F...
# 39898      0  MUSLIM WOMAN BUSTED Buying Soda With Food Stam...
# 39902      0  IS OUR FIRST AMENDMENT RIGHT Being Stolen By T...
# 39934      0  THIS VIDEO WILL DESTROY “Black Lives Matter”…S...
#
#                                                     text       subject  \
# 8970                                                      politicsNews
# 29357  https://100percentfedup.com/served-roy-moore-v...      politics
# 30922                                                         politics
# 31040                                                         politics
# 31116                                             Enjoy:      politics
# ...                                                  ...           ...
# 39866                                                        left-news
# 39894                                                        left-news
# 39898                                                        left-news
# 39902             ***WARNING***This video is GRAPHIC!***     left-news
# 39934                                                        left-news
#
#                                                     date  text_len  title_len
# 8970                                      June 16, 2016          0          4
# 29357  https://100percentfedup.com/served-roy-moore-v...         1          1
# 30922                                       May 10, 2017         0         15
# 31040                                       Apr 26, 2017         0         19
# 31116                                       Apr 17, 2017         1          7
# ...                                                  ...       ...        ...
# 39866                                        Oct 5, 2016         0         15
# 39894                                        Oct 1, 2016         0         17
# 39898                                       Sep 29, 2016         0         17
# 39902                                       Sep 29, 2016         4         29
# 39934                                       Sep 22, 2016         0          9
#
# [823 rows x 7 columns]

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data=df, x='text_len', hue='label', bins=50)
# Out:
# <Axes: xlabel='text_len', ylabel='Count'>

# %%
df[df['title_len'] == 1]#['label'].value_counts()
# Out:
#        label                                              title  \
# 29357      0  https://100percentfedup.com/served-roy-moore-v...
# 35506      0  https://100percentfedup.com/video-hillary-aske...
# 35507      0  https://100percentfedup.com/12-yr-old-black-co...
# 35838      0  https://fedup.wpengine.com/wp-content/uploads/...
# 35839      0  https://fedup.wpengine.com/wp-content/uploads/...
# 37431      0  https://fedup.wpengine.com/wp-content/uploads/...
# 37432      0  https://fedup.wpengine.com/wp-content/uploads/...
# 38932      0                                           Homepage
#
#                                                     text          subject  \
# 29357  https://100percentfedup.com/served-roy-moore-v...         politics
# 35506  https://100percentfedup.com/video-hillary-aske...         politics
# 35507  https://100percentfedup.com/12-yr-old-black-co...         politics
# 35838  https://fedup.wpengine.com/wp-content/uploads/...         politics
# 35839  https://fedup.wpengine.com/wp-content/uploads/...         politics
# 37431  https://fedup.wpengine.com/wp-content/uploads/...  Government News
# 37432  https://fedup.wpengine.com/wp-content/uploads/...  Government News
# 38932  [vc_row][vc_column width= 1/1 ][td_block_trend...        left-news
#
#                                                     date  text_len  title_len
# 29357  https://100percentfedup.com/served-roy-moore-v...         1          1
# 35506  https://100percentfedup.com/video-hillary-aske...         1          1
# 35507  https://100percentfedup.com/12-yr-old-black-co...         1          1
# 35838  https://fedup.wpengine.com/wp-content/uploads/...         1          1
# 35839  https://fedup.wpengine.com/wp-content/uploads/...         1          1
# 37431  https://fedup.wpengine.com/wp-content/uploads/...         1          1
# 37432  https://fedup.wpengine.com/wp-content/uploads/...         1          1
# 38932  MSNBC HOST Rudely Assumes Steel Worker Would N...        53          1

# %%
df.iloc[38932,2]
# Out:
# '[vc_row][vc_column width= 1/1 ][td_block_trending_now limit= 5 ][td_block_big_grid sort= featured ][/vc_column][/vc_row][vc_row] [vc_column width= 2/3 ][td_block_5 limit= 24  custom_title= HOT OFF THE PRESS!  td_filter_default_txt= All  ajax_pagination= load_more  border_top= no_border_top ] [/vc_column][vc_column width= 1/3 ][vc_widget_sidebar sidebar_id= td-default ][/vc_column] [/vc_row][vc_row][vc_column width= 1/1 ][td_block_14 limit= 3  custom_title= EVEN MORE NEWS  td_filter_default_txt= All  ajax_pagination= next_prev  header_color= #288abf ][/vc_column] [/vc_row]'

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data=df, x='title_len', hue='label', bins=50)
# Out:
# <Axes: xlabel='title_len', ylabel='Count'>
